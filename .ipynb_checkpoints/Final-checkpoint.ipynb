# %% [markdown]
# <h1>Mục lục <span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import" data-toc-modified-id="Import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import</a></span></li><li><span><a href="#Đọc-dữ-liệu-từ-file-csv" data-toc-modified-id="Đọc-dữ-liệu-từ-file-csv-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Đọc dữ liệu từ file csv</a></span></li><li><span><a href="#Đưa-ra-câu-hỏi-cho-dữ-liệu" data-toc-modified-id="Đưa-ra-câu-hỏi-cho-dữ-liệu-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Đưa ra câu hỏi cho dữ liệu</a></span></li><li><span><a href="#Khám-phá-dữ-liệu" data-toc-modified-id="Khám-phá-dữ-liệu-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Khám phá dữ liệu</a></span><ul class="toc-item"><li><span><a href="#Thống-kê-dòng,cột.." data-toc-modified-id="Thống-kê-dòng,cột..-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Thống kê dòng,cột..</a></span></li><li><span><a href="#Visualize-các-cột-quan-trọng" data-toc-modified-id="Visualize-các-cột-quan-trọng-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Visualize các cột quan trọng</a></span></li></ul></li><li><span><a href="#Tách-các-tập" data-toc-modified-id="Tách-các-tập-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Tách các tập</a></span><ul class="toc-item"><li><span><a href="#Kích-thước-dữ-liệu-sau-khi-tách" data-toc-modified-id="Kích-thước-dữ-liệu-sau-khi-tách-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Kích thước dữ liệu sau khi tách</a></span></li></ul></li><li><span><a href="#Phương-pháp-đánh-giá-1" data-toc-modified-id="Phương-pháp-đánh-giá-1-6"><span class="toc-item-num">6&nbsp;&nbsp;</span><strong>Phương pháp đánh giá 1</strong></a></span><ul class="toc-item"><li><span><a href="#Tách-tập-validation-từ-tập-train" data-toc-modified-id="Tách-tập-validation-từ-tập-train-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Tách tập validation từ tập train</a></span></li><li><span><a href="#Tiền-xử-lí-(-tập-huấn-luyện-)" data-toc-modified-id="Tiền-xử-lí-(-tập-huấn-luyện-)-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Tiền xử lí ( tập huấn luyện )</a></span><ul class="toc-item"><li><span><a href="#Điền-giá-trị-thiếu" data-toc-modified-id="Điền-giá-trị-thiếu-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Điền giá trị thiếu</a></span></li></ul></li><li><span><a href="#Tìm-mô-hình-tốt-nhất" data-toc-modified-id="Tìm-mô-hình-tốt-nhất-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Tìm mô hình tốt nhất</a></span><ul class="toc-item"><li><span><a href="#Giá-trị-alpha-&amp;-độ-lỗi-tốt-nhất" data-toc-modified-id="Giá-trị-alpha-&amp;-độ-lỗi-tốt-nhất-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Giá trị alpha &amp; độ lỗi tốt nhất</a></span><ul class="toc-item"><li><span><a href="#Nhận-xét-:" data-toc-modified-id="Nhận-xét-:-6.3.1.1"><span class="toc-item-num">6.3.1.1&nbsp;&nbsp;</span>Nhận xét :</a></span></li></ul></li><li><span><a href="#Fit-mô-hình-với-alpha-và-iter-tốt-nhất" data-toc-modified-id="Fit-mô-hình-với-alpha-và-iter-tốt-nhất-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Fit mô hình với alpha và iter tốt nhất</a></span></li><li><span><a href="#Kiểm-tra-cuối-cùng-của-mô-hình-với-tập-test" data-toc-modified-id="Kiểm-tra-cuối-cùng-của-mô-hình-với-tập-test-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>Kiểm tra cuối cùng của mô hình với tập test</a></span></li></ul></li></ul></li><li><span><a href="#Phương-pháp-đánh-giá-2" data-toc-modified-id="Phương-pháp-đánh-giá-2-7"><span class="toc-item-num">7&nbsp;&nbsp;</span><strong>Phương pháp đánh giá 2</strong></a></span><ul class="toc-item"><li><span><a href="#Tách-tập-validation-từ-tập-train" data-toc-modified-id="Tách-tập-validation-từ-tập-train-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Tách tập validation từ tập train</a></span></li><li><span><a href="#Tìm-mô-hình-tốt-nhất" data-toc-modified-id="Tìm-mô-hình-tốt-nhất-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Tìm mô hình tốt nhất</a></span></li><li><span><a href="#Đánh-giá-sơ-bộ" data-toc-modified-id="Đánh-giá-sơ-bộ-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Đánh giá sơ bộ</a></span></li><li><span><a href="#Fit-mô-hình-với-C-và-max_iter-tốt-nhất" data-toc-modified-id="Fit-mô-hình-với-C-và-max_iter-tốt-nhất-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Fit mô hình với C và max_iter tốt nhất</a></span></li><li><span><a href="#Kiểm-tra-cuối-cùng-với-tập-test" data-toc-modified-id="Kiểm-tra-cuối-cùng-với-tập-test-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Kiểm tra cuối cùng với tập test</a></span></li></ul></li><li><span><a href="#Phương-pháp-đánh-giá-3" data-toc-modified-id="Phương-pháp-đánh-giá-3-8"><span class="toc-item-num">8&nbsp;&nbsp;</span><strong>Phương pháp đánh giá 3</strong></a></span><ul class="toc-item"><li><span><a href="#Tách-tập-validation-từ-tập-train" data-toc-modified-id="Tách-tập-validation-từ-tập-train-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Tách tập validation từ tập train</a></span></li><li><span><a href="#Tiền-xử-lí-(-tập-huấn-luyện-)" data-toc-modified-id="Tiền-xử-lí-(-tập-huấn-luyện-)-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Tiền xử lí ( tập huấn luyện )</a></span><ul class="toc-item"><li><span><a href="#Điền-giá-trị-thiếu" data-toc-modified-id="Điền-giá-trị-thiếu-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Điền giá trị thiếu</a></span></li></ul></li><li><span><a href="#Mô-hình-MLPRegressor" data-toc-modified-id="Mô-hình-MLPRegressor-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Mô hình <strong><code>MLPRegressor</code></strong></a></span><ul class="toc-item"><li><span><a href="#Nhận-xét-:" data-toc-modified-id="Nhận-xét-:-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Nhận xét :</a></span></li><li><span><a href="#Kiểm-tra-cuối-cùng" data-toc-modified-id="Kiểm-tra-cuối-cùng-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span>Kiểm tra cuối cùng</a></span></li></ul></li><li><span><a href="#Mô-hình-SoftmaxRegression" data-toc-modified-id="Mô-hình-SoftmaxRegression-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Mô hình <strong><code>SoftmaxRegression</code></strong></a></span><ul class="toc-item"><li><span><a href="#Đánh-giá-sơ-bộ" data-toc-modified-id="Đánh-giá-sơ-bộ-8.4.1"><span class="toc-item-num">8.4.1&nbsp;&nbsp;</span>Đánh giá sơ bộ</a></span></li><li><span><a href="#Kiểm-tra-cuối-cùng" data-toc-modified-id="Kiểm-tra-cuối-cùng-8.4.2"><span class="toc-item-num">8.4.2&nbsp;&nbsp;</span>Kiểm tra cuối cùng</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Đồ Án Cuối Kì Môn Khoa Học Dữ Liệu
#
# **Chủ đề: Sử dụng các mô hình và cách tiền xử lí khác nhau để dự đoán khoảng người chết do dịch bệnh COVID-19 của các quốc gia trên thế giới.**
#
#
#
#
# **Giới thiệu thành viên**
#
# - *Họ tên:* **Trần Ngọc Tịnh**
#   *MSSV:* **18120597**
#
#
#
#
# - *Họ tên:* **Nguyễn Ngọc Năng Toàn**
#   *MSSV:* **18120600**

# %% [markdown]
# --- ---

# %% [markdown]
# ## Import

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns # seaborn là thư viện được xây trên matplotlib, giúp việc visualization đỡ khổ hơn
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.neural_network import MLPClassifier
from sklearn import set_config
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LogisticRegression
import warnings


set_config(display='diagram') # Để trực quan hóa pipeline

# %% [markdown]
# ## Đọc dữ liệu từ file csv

# %%
data_df = pd.read_csv('data\data.csv', 
                      index_col=0) # Cho cột index là cột 0 (PassengerId)
data_df.head()
# Out:
#              confirmed  recovered  deaths  population  sq_km_area  \
# Country
# Afghanistan      51526      41727    2191  35530081.0    652090.0
# Albania          58316      33634    1181   2930187.0     28748.0
# Algeria          99610      67127    2756  41318142.0   2381741.0
# Andorra           8049       7432      84     76965.0       468.0
# Angola           17553      11044     405  29784193.0   1246700.0
#
#             life_expectancy elevation_in_meters continent abbreviation  \
# Country
# Afghanistan            45.9                 NaN      Asia           AF
# Albania                71.6                 NaN    Europe           AL
# Algeria                69.7                 800    Africa           DZ
# Andorra                83.5               1,996    Europe           AD
# Angola                 38.3               1,112    Africa           AO
#
#                               location   iso      capital_city       lat  \
# Country
# ...

# %% [markdown]
# ## Đưa ra câu hỏi cho dữ liệu
#
#
# Câu hỏi nhóm em đặt ra là dự đoán số lượng người chết của mỗi quốc gia,cột **output** là `deaths`. Nhưng vấn đề nhóm gặp phải đó là dữ liệu này quá ít. Chỉ có 147 quốc gia, bên cạnh đó dữ liệu này còn rời rạc. Dẫn đến việc dự đoán một con số chính xác có kết quả là khá tệ, nếu như không muốn nói là kết quả không đúng kết quả nào trong bộ test.
#
# Nhóm đã quyết định thay vì dự đoán một con số chính xác thì sẽ dự đoán một khoảng, các khoảng thì sẽ được trình bày ở phần phân tích dữ liệu phía dưới.

# %% [markdown]
# ## Khám phá dữ liệu

# %% [markdown]
# ### Thống kê dòng,cột..

# %% [markdown]
# **Dữ liệu có bao nhiêu dòng và bao nhiêu cột?**

# %%
data_df.shape
# Out:
# (173, 15)

# %% [markdown]
# **Dữ liệu có các dòng bị lặp không?**

# %%
data_df.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Kiểu dữ liệu của các cột**

# %%
data_df.dtypes
# Out:
# confirmed                int64
# recovered                int64
# deaths                   int64
# population             float64
# sq_km_area             float64
# life_expectancy         object
# elevation_in_meters     object
# continent               object
# abbreviation            object
# location                object
# iso                    float64
# capital_city            object
# lat                    float64
# long                   float64
# updated                 object
# dtype: object

# %% [markdown]
# **Ý nghĩa của các cột**

# %%
with open('description.txt', 'r',encoding="utf8") as f:
    print(f.read())
# Out:
# Country: Tên quốc gia.
# confirmed: Số ca mắc Covid-19 đã xác nhận (int).
# recovered: Số ca hồi phục (int).
# deaths: Số ca tử vong (int).
# population: Dân số của quốc gia (float).
# sq_km_area: Diện tích của quốc gia (float).
# life_expectancy: Tuổi thọ trung bình của quốc gia.
# elevation_in_meters: Độ cao tính bằng mét so với mật nước biển.
# continent: Quốc gia thuộc lục địa nào.
# abbreviation : Tên viết tắt của quốc gia.
# location: Khu vực của quốc gia.
# iso: Mã Code của quốc gia.
# capital_city: Tên thủ đô của quốc gia.
# lat: Vĩ độ của quốc gia.
# long: Kinh độ của quốc gia.
# updated: Ngày,tháng,năm cập nhật.

# %% [markdown]
# ### Visualize các cột quan trọng

# %% [markdown]
# **Visualize cột population**
#
#
#
#
# Ở cột dân số, ta có thể thấy top 2 dân số có số dân vượt trội là **Trung Quốc**, **Ấn Độ**

# %%
data_df['population'].nlargest(n=20).plot(kind='barh')
plt.show()

# %% [markdown]
# **Visualize cột confirmed**
#
#
# Sau khi sử dụng đồ thị thì ta có thể thấy nước **Mỹ** có nhiều case *Covid* nhất tiếp theo là **Ấn Độ** và **Brazil**. Mặc dù là nước nảy sinh đầu tiên ra Covid-19 và có dân số đông nhất thế giới nhưng trong top 20 chúng ta không hề thấy **Trung Quốc**.

# %%
data_df['confirmed'].nlargest(n=20).plot(kind='barh')
plt.show()

# %% [markdown]
# **Visualize cột recovered**
#
# Hiển thị 20 nước có số ca hồi phục nhiều nhất trong dữ liệu

# %%
data_df['recovered'].nlargest(n=20).plot(kind='barh')
plt.show()

# %% [markdown]
# **Visualize cột deaths**
#
# Hiển thị số ca tử vong của các nước.Đây là cột của câu hỏi chúng ta cần tìm.
#
# Dựa vào biểu đồ,chúng ta có thể thấy số lượng tử vong của các quốc gia đa phần nằm dưới **5000**. Nên em sẽ chuyển dữ liệu cột `deaths` thành **5** khoảng như sau:
#
# - 0 -> 100: Lưu vào **0**
# - 100 -> 500: Lưu vào **1**
# - 500 -> 1500: Lưu vào **2**
# - 1500 -> 5000: Lưu vào **3**
# - 5000 -> Max:  Lưu vào **4**

# %%
data_df['deaths'].plot(use_index=False,kind='line',figsize=(30,10))
plt.show()

# %% [markdown]
# Chuyển đổi dữ liệu cột `output` về các nhóm.

# %%
data_df.loc[(data_df['deaths']>=0)&(data_df['deaths']<100),'deaths'] = 0
data_df.loc[(data_df['deaths']>=100)&(data_df['deaths']<500),'deaths'] = 1
data_df.loc[(data_df['deaths']>=500)&(data_df['deaths']<1500),'deaths'] = 2
data_df.loc[(data_df['deaths']>=1500)&(data_df['deaths']<5000),'deaths'] = 3  
data_df.loc[(data_df['deaths']>=5000,'deaths')] =4

# %% [markdown]
# Kết quả sau khi chuyển đổi.

# %%
data_df['deaths'].unique()
# Out:
# array([3, 2, 0, 1, 4], dtype=int64)

# %% [markdown]
# ## Tách các tập

# %% [markdown]
# - Tách thành 2 phần **X** và **y**. Với X là `input`, y là `output`.

# %%
y_sr = data_df["deaths"] # sr là viết tắt của series
X_df = data_df.drop("deaths", axis=1)

# %% [markdown]
# - Ban đầu em sẽ chi tập `test` bằng **20%** và tập `train` là **80%**.Từ tập train này em sẽ chia thành các phần khác nhau tùy thuộc vào mỗi phương pháp đánh giá.

# %%
train_X, test_X, train_y, test_y = train_test_split(X_df,y_sr,test_size=0.2, random_state=0)

# %% [markdown]
# ### Kích thước dữ liệu sau khi tách

# %% [markdown]
# **In các kích thước sau khi chia**

# %%
print("shape train_X :", train_X.shape)
print("shape train_y :", train_y.shape)
print("shape val_X :", test_X.shape)
print("shape val_y :", test_y.shape)
# Out:
# shape train_X : (138, 14)
# shape train_y : (138,)
# shape val_X : (35, 14)
# shape val_y : (35,)

# %% [markdown]
# ## **Phương pháp đánh giá 1**
#
# Trong phương pháp này nhóm sẽ xóa các cột mà nhóm nghĩ sẽ không ảnh hưởng đến `output`.
#
# - `abbreviation`: cột này có ý nghĩa là tên viết tắt của quốc gia.
# - `capital_city`: Giá trị tên thủ đô của quốc gia.
# - `updated`: Thời gian cập nhật của dữ liệu, theo mình quan sát thì dữ liệu của các quốc gia hầu như đều được cập nhật có thời gian khá tương tự nhau.
#
#
# Tiếp theo là 2 giá trị hiển thị vị trí của quốc gia. Theo mình nghĩ 2 giá trị này chỉ là hiển thị vị trí kinh độ,vĩ độ không ảnh hưởng đến số lượng người chết,mỗi quốc gia sẽ có 1 giá trị khác nhau.
# - `lat`: Giá trị vĩ độ của quốc gia.
# - `long`: Giá trị kinh độ của quốc gia
#
# Mô hình nhóm chọn là **`MLPRegressor`**

# %% [markdown]
# ### Tách tập validation từ tập train

# %% [markdown]
# - Em sẽ chia tập `validation` bằng **20%** và tập `train` **còn lại** là **80%**

# %%
train_1_X, val_1_X, train_1_y, val_1_y = train_test_split(train_X,train_y,test_size=0.2, random_state=0)

# %% [markdown]
# **Kích thước các tập sau khi chia**

# %%
print("shape train_X :", train_1_X.shape)
print("shape train_y :", train_1_y.shape)
print("shape val_X :", val_1_X.shape)
print("shape val_y :", val_1_y.shape)
# Out:
# shape train_X : (110, 14)
# shape train_y : (110,)
# shape val_X : (28, 14)
# shape val_y : (28,)

# %% [markdown]
# **Kiểm tập train_X dùng chung cho các mô hình và tập test không bị thay đổi**

# %%
print("shape train_X :", train_X.shape)
print("shape train_y :", train_y.shape)
print("shape val_X :", test_X.shape)
print("shape val_y :", test_y.shape)
# Out:
# shape train_X : (138, 14)
# shape train_y : (138,)
# shape val_X : (35, 14)
# shape val_y : (35,)

# %% [markdown]
# ### Tiền xử lí ( tập huấn luyện )

# %% [markdown]
# **Class Tiền xử lí**
#
#    - Class này sẽ xóa các cột `abbreviation`, `capital_city`, `updated`,`lat`,`long`.
#
#    - Chuyển dữ liệu cột `deaths` thành **5** khoảng như sau(nguyên nhân chuyển mình có đề cập và thực hiện ở phần ***Khám phá dữ liệu***:
#
#         - 0 -> 100: Lưu vào **0**
#         - 100 -> 500: Lưu vào **1**
#         - 500 -> 1500: Lưu vào **2**
#         - 1500 -> 5000: Lưu vào **3**
#         - 5000 -> Max:  Lưu vào **4**
#
# - Nhận thấy kiểu dữ liệu của `life_expectancy` là **object** nhưng cột này lại hiển thị độ tuổi. Nên chúng ta sẽ gán lại kiểu giá trị cột này về **float**

# %%
class ColAdderDropper(BaseEstimator, TransformerMixin):
    def fit(self, X_df, y=None):
        return self
    def transform(self, X_df, y=None):
        df = X_df.copy()
        unused_cols = ['abbreviation','capital_city', 'updated','lat','long']
        df=df.drop(unused_cols,axis=1)
        df=df.astype({'confirmed':'float64','recovered':'float64'})
        df['elevation_in_meters'] = pd.to_numeric(df['elevation_in_meters'],errors='coerce')
        df['life_expectancy'] = pd.to_numeric(df['life_expectancy'],errors='coerce')
        return df

# %% [markdown]
# **Fit và Transform tập `train_1_X` để xem  dữ liệu sau khi tiền xử lí.**

# %%
col_adderdropper = ColAdderDropper()
col_adderdropper.fit(train_1_X)
col_adderdropper.transform(train_1_X).head()
# Out:
#             confirmed  recovered  population  sq_km_area  life_expectancy  \
# Country
# Zambia        20997.0    18773.0  17094130.0    752618.0             37.2
# Luxembourg    46415.0    40978.0    583455.0      2586.0             77.1
# Bhutan          689.0      449.0    807610.0     47000.0             52.4
# Mozambique    18642.0    16663.0  29668834.0    801590.0             37.5
# Eritrea        1252.0      643.0   5068831.0    117600.0             55.8
#
#             elevation_in_meters continent                   location    iso
# Country
# Zambia                      NaN    Africa             Eastern Africa  894.0
# Luxembourg                325.0    Europe             Western Europe  442.0
# Bhutan                      NaN      Asia  Southern and Central Asia   64.0
# Mozambique                345.0    Africa             Eastern Africa  508.0
# Eritrea                   853.0    Africa             Eastern Africa  232.0

# %% [markdown]
# **Kiểu dữ liệu của các cột sau xử lí**

# %%
col_adderdropper.transform(train_1_X).dtypes
# Out:
# confirmed              float64
# recovered              float64
# population             float64
# sq_km_area             float64
# life_expectancy        float64
# elevation_in_meters    float64
# continent               object
# location                object
# iso                    float64
# dtype: object

# %% [markdown]
# **Kích thước tập sau khi tiền xử lí**

# %%
col_adderdropper.transform(train_1_X).shape
# Out:
# (110, 9)

# %% [markdown]
# **Thống kê các giá trị NA của từng cột**

# %%
col_adderdropper.transform(train_1_X).isna().sum()
# Out:
# confirmed               0
# recovered               0
# population              1
# sq_km_area              1
# life_expectancy         2
# elevation_in_meters    33
# continent               1
# location                1
# iso                     2
# dtype: int64

# %% [markdown]
# **Kiểm tra sau khi fit&transform tập train_X không bị thay đổi**

# %%
train_X.shape
# Out:
# (138, 14)

# %% [markdown]
# #### Điền giá trị thiếu

# %% [markdown]
# - Sau khi loại bỏ các cột mà em nghĩ là không cần thiết thì chúng ta còn lại các cột sau đây: `confirmed`,`recovered`,`population`,`sq_km_area`,`life_expectancy`,`iso`,`elevation_in_meters`.
#
#
# - Trong đó:
#
#     - Các cột dạng số là `confirmed`,`recovered`,`population`,`sq_km_area`,`life_expectancy`,`iso`,`elevation_in_meters`.
#
#     - Các cột không phải dạng số là:
#         - `loacation` ta nhận thấy đây không phải là cột có thứ tự:
#
#             - Ta sẽ điền các giá trị thiếu bằng mode.
#             - Chuyển sang dạng số bằng phương pháp mã One-hot.
#
# - Sau đó chúng ta sẽ dùng hàm chuẩn hóa `StandardScaler` của **Sklearn** để các thuật toán cực tiểu hóa hội tụ nhanh hơn.

# %%
nume_cols=['confirmed','recovered','population','sq_km_area','iso','elevation_in_meters','life_expectancy']
cate_cols=['continent','location']

mean = SimpleImputer(strategy='mean')
mode = SimpleImputer(strategy='most_frequent') 
mode_encode = make_pipeline(mode,OneHotEncoder(handle_unknown='ignore'))

colTransform = ColumnTransformer([('mean_for_nume_cols',mean, nume_cols),\
                                 ('mode_encode_for_cate_cols',mode_encode,cate_cols)])

colNormalize = StandardScaler(with_mean=False)
preprocess_pipeline = make_pipeline(col_adderdropper,colTransform,colNormalize)

preprocessed_train_X=preprocess_pipeline.fit_transform(train_1_X)

preprocess_pipeline
# Out:
# Pipeline(steps=[('coladderdropper', ColAdderDropper()),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('mean_for_nume_cols',
#                                                   SimpleImputer(),
#                                                   ['confirmed', 'recovered',
#                                                    'population', 'sq_km_area',
#                                                    'iso', 'elevation_in_meters',
#                                                    'life_expectancy']),
#                                                  ('mode_encode_for_cate_cols',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
# ...

# %% [markdown]
# ### Tìm mô hình tốt nhất

# %% [markdown]
# - Em sử dụng mô hình **`Neural Net`** để phân lớp. Với các siêu tham số `activation`= **'tanh'**, `solver`= **'lbfgs'**, `random_state`= **0**
#
# - Siêu tham số `alpha` (mức độ L2 regularization hay weight decay) của `MLPClassifier` với 5 giá trị khác nhau: 0.1, 1, 10, 100, 1000.
#
# - Siêu tham số `max_iter`là số lần lặp tối đa với 5 giá trị 100,500,1000,2000,2500
#
# - Siêu tham số `hidden_layer_sizes` -2  là số lớp ẩn với 5 giá trị 100,500,1000,2000,2500
#
#
#
# Sau khi chạy thì có vài dòng thông báo màu **đỏ**, đây chỉ là thông báo hiển thị chưa hội tụ(do `iter max` nhỏ).Em đã sử dụng thư viện **warnings** để ẩn nó đi.
#
# Tổng cộng có **3** vòng lặp for đẫn đến quá trình chạy hơi lâu(khoảng 30s).

# %%
warnings.filterwarnings('ignore')
mlpclassifier = MLPClassifier(activation='tanh', solver='lbfgs', random_state=0)
full_pipeline = make_pipeline(col_adderdropper, colTransform, colNormalize, mlpclassifier)
train_errs = []
val_errs = []
alphas = [0.1, 1, 10, 100, 1000]
max_iter= [100,500,1000,2000,2500]
hidden_layer_sizes=[2,5,10,20,40]
best_val_err = float('inf'); best_alpha = None;best_iter=None;best_hidden_layer=None
for hidden_layer in hidden_layer_sizes:
    for iter_ in max_iter:
        for alpha in alphas:
            full_pipeline.set_params(mlpclassifier__alpha=alpha,mlpclassifier__max_iter=iter_,\
                                     mlpclassifier__hidden_layer_sizes=hidden_layer)
            full_pipeline.fit(train_1_X, train_1_y)
            full_pipeline.predict(val_1_X)
            train_score = full_pipeline.score(train_1_X,train_1_y)
            val_score = full_pipeline.score(val_1_X, val_1_y)
            train_err,val_err = (1 - train_score) * 100, (1 - val_score) * 100
            train_errs.append(train_err)
            val_errs.append(val_err)
            if best_val_err > val_err:
                best_val_err = val_err
                best_alpha = alpha
                best_iter=iter_
                best_hidden_layer=hidden_layer

# %% [markdown]
# #### Giá trị alpha & độ lỗi tốt nhất

# %% [markdown]
# Sau khi chạy vòng lặp thì thu được kết quả các giá trị **`best_val_err`**,**`best_alpha`**,**`best_iter`**,**`best_hidden_layer`** như sau:

# %%
print("best_val_err : ", best_val_err)
print("best_alpha : " ,best_alpha)
print("best_iter :",best_iter)
print("best_hidden_layer",best_hidden_layer)
# Out:
# best_val_err :  35.71428571428571
# best_alpha :  0.1
# best_iter : 500
# best_hidden_layer 2

# %% [markdown]
# **Đồ thị 2 độ lỗi train và validation**

# %%
val_errs = np.array(val_errs)
train_errs=np.array(train_errs)

# %%
plt.figure(figsize=(30,20))
plt.plot(val_errs)
plt.plot(train_errs)
plt.show()

# %% [markdown]
# ##### Nhận xét :
#
# **Đường màu xanh là giá trị validation_err**
#
# **Đường màu đỏ là giá trị train_err**
#
# **Với các giá trị siêu tham số càng lớn, thì dữ liệu càng bị OverFitting**

# %% [markdown]
# #### Fit mô hình với alpha và iter tốt nhất

# %% [markdown]
# **Huấn luyện lại `full_pipeline` trên `train_X` và `train_y` (tập huấn luyện + tập validation) với `best_alpha`,`best_iter` và `best_hidden_layer` tìm được ở trên để ra được mô hình cụ thể cuối cùng.**

# %%
full_pipeline.set_params(mlpclassifier__max_iter=iter_,mlpclassifier__alpha=best_alpha,\
                         mlpclassifier__hidden_layer_sizes=best_hidden_layer)
full_pipeline.fit(train_X, train_y)
# Out:
# Pipeline(steps=[('coladderdropper', ColAdderDropper()),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('mean_for_nume_cols',
#                                                   SimpleImputer(),
#                                                   ['confirmed', 'recovered',
#                                                    'population', 'sq_km_area',
#                                                    'iso', 'elevation_in_meters',
#                                                    'life_expectancy']),
#                                                  ('mode_encode_for_cate_cols',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
# ...

# %% [markdown]
# #### Kiểm tra cuối cùng của mô hình với tập test

# %% [markdown]
# **Đây là kết quả khá tốt đối với tập dữ liệu đầu vào của em khá nhỏ**

# %%
score_1 = full_pipeline.score(test_X,test_y)
score_1
# Out:
# 0.7142857142857143

# %% [markdown]
# ## **Phương pháp đánh giá 2**

# %% [markdown]
# Ở phương pháp đánh giá thứ 2:
#
# - Về phần tiền xử lí em vẫn sử dụng cách tương tự với phương pháp đánh giá 1.
#
#
# - Mô hình ở phương pháp 2 nhóm sử dụng là **`SoftmaxRegression`**
#
# Theo kiến thức của em thì  **`SoftmaxRegression`** là một thuật toán phân loại áp dụng cho bài toán phân nhiều lớp, thích hợp với câu hỏi được đặt ra của em.

# %% [markdown]
# ### Tách tập validation từ tập train

# %% [markdown]
# **Tương tự với phương pháp 1**
#
# - Em sẽ chia tập `validation` bằng **20%** và tập `train` **còn lại** là **80%**.
#
#
# - Và lưu vào các biến `train_2_X`, `val_2_X`, `train_2_y`, `val_2_y`.

# %%
train_2_X, val_2_X, train_2_y, val_2_y = train_test_split(train_X,train_y,test_size=0.2, random_state=0)

# %% [markdown]
# ### Tìm mô hình tốt nhất

# %% [markdown]
# - Em sử dụng mô hình **`SoftmaxRegression`** để phân lớp. Với các siêu tham số **`multi_class='multinomial'`**, nếu để `multi_class`mặc định thì sẽ là mô hình `LogisticRegression`.
#
# - Siêu tham số `C` là số lớp của mô hình  `SoftmaxRegression` với 6 giá trị khác nhau: `1, 10, 100, 1000, 10000, 100000`. Lưu ý là nếu `C` càng lớn thì mô hình sẽ chạy càng lâu.
#
# - Siêu tham số `max_iter`là số lần lặp tối đa với 5 giá trị `100, 500, 1000, 2000, 2500`

# %% [markdown]
# **Khởi tạo mô hình**

# %%
logregmodel = LogisticRegression(multi_class='multinomial')
full_pipeline_2 = make_pipeline(col_adderdropper, colTransform, colNormalize,logregmodel)
full_pipeline_2
# Out:
# Pipeline(steps=[('coladderdropper', ColAdderDropper()),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('mean_for_nume_cols',
#                                                   SimpleImputer(),
#                                                   ['confirmed', 'recovered',
#                                                    'population', 'sq_km_area',
#                                                    'iso', 'elevation_in_meters',
#                                                    'life_expectancy']),
#                                                  ('mode_encode_for_cate_cols',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
# ...

# %% [markdown]
# **Dùng 2 vòng lặp for để tìm giá trị `C` và `max_iter` tốt nhất cho mô hình.**
#
#
#
# - **Sau khi chạy thì có vài dòng thông báo màu đỏ, đây chỉ là thông báo hiển thị chưa hội tụ(do `iter max` nhỏ)**.Em đã sử dụng thư viện **warnings** để ẩn nó đi.
#
#
#
# - Sẽ có tất cả **30** lần chạy sau **2**vòng lặp.

# %%
warnings.filterwarnings('ignore')
train_errs = []
val_errs = []
C = [1, 10, 100, 1000, 10000, 100000]
max_iters= [100, 500, 1000, 2000, 2500]
best_val_err = float('inf'); best_C = None;best_iter=None

for c in C:
    for iter_ in max_iters:
        full_pipeline_2.set_params(logisticregression__C=c,logisticregression__max_iter= iter_)
        full_pipeline_2.fit(train_2_X, train_2_y)
        full_pipeline_2.predict(val_2_X)
        train_score = full_pipeline_2.score(train_2_X,train_2_y)
        val_score = full_pipeline_2.score(val_2_X, val_2_y)
        train_err, val_err = (1 - train_score) * 100, (1 - val_score) * 100
        train_errs.append(train_err)
        val_errs.append(val_err)
        if best_val_err > val_err:
            best_val_err = val_err
            best_C = c
            best_iter=iter_

# %% [markdown]
# **In ra màn hình các giá trị tốt nhất vừa tìm được**

# %%
print("best_val_err :" , best_val_err)
print("best_C :",best_C)
print("best_iter :", best_iter)
# Out:
# best_val_err : 32.14285714285714
# best_C : 100
# best_iter : 500

# %% [markdown]
# **Trực quan hóa kết quả**

# %%
train_errs_df = pd.DataFrame(data=np.array(train_errs).reshape(len(C), -1),
                             index=C, columns=max_iters)
val_errs_df = pd.DataFrame(data=np.array(val_errs).reshape(len(C), -1), 
                           index=C, columns=max_iters)
min_err = min(min(train_errs), min(val_errs))
max_err = max(max(train_errs), max(val_errs))
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)

sns.heatmap(train_errs_df,vmin=min_err, vmax=max_err, square=True, annot=True, 
            cbar=False, fmt='.1f', cmap='Reds')
plt.title('train errors'); plt.xlabel('max_iters'); plt.ylabel('C');

min_err = min(min(train_errs), min(val_errs))
max_err = max(max(train_errs), max(val_errs))
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)

sns.heatmap(val_errs_df,vmin=min_err, vmax=max_err, square=True, annot=True, 
            cbar=False, fmt='.1f', cmap='Reds')
plt.title('validation errors'); plt.xlabel('max_iters'); plt.ylabel('C');

# %% [markdown]
# ### Đánh giá sơ bộ
#
# **Giá trị C càng lớn thì độ lỗi ở tập train hạ về 0 nhưng ở tập validation thì càng tăng => Mô hình đã bị OverFitting**

# %% [markdown]
# ### Fit mô hình với C và max_iter tốt nhất

# %% [markdown]
# **Huấn luyện lại `full_pipeline` trên `train_X` và `train_y` (tập huấn luyện + tập validation) với `best_C` và `best_iter` tìm được ở trên để ra được mô hình cụ thể cuối cùng.**

# %%
full_pipeline_2.set_params(logisticregression__C=best_C,logisticregression__max_iter= best_iter)
full_pipeline_2.fit(train_X, train_y)
# Out:
# Pipeline(steps=[('coladderdropper', ColAdderDropper()),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('mean_for_nume_cols',
#                                                   SimpleImputer(),
#                                                   ['confirmed', 'recovered',
#                                                    'population', 'sq_km_area',
#                                                    'iso', 'elevation_in_meters',
#                                                    'life_expectancy']),
#                                                  ('mode_encode_for_cate_cols',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
# ...

# %% [markdown]
# ### Kiểm tra cuối cùng với tập test

# %% [markdown]
# **Kết quả  so với phương pháp một(dùng `Neural Net`) là thấp hơn khá nhiều.**

# %%
score_2 = full_pipeline_2.score(test_X,test_y)
score_2
# Out:
# 0.5428571428571428

# %% [markdown]
# ## **Phương pháp đánh giá 3**
#
#
#
# Ở phương pháp đánh giá 3, em sẽ thay đổi cách tiền xử lí của dữ liệu như sau.
#
# - Ở phương pháp đánh giá 1, 2 em đã xóa 2 cột kinh độ( `long`), vĩ độ( `lat`) và giữ lại thuộc tính để xác định vị trí địa lí là `loacation` và `continent`.
#
# - Trong phương pháp này nhóm sẽ làm ngược lại để thử nếu ta thay đổi tập dữ liệu thì kết quả dự đoán cột `output` có tăng lên hay không?
#
#     - Các cột sẽ xóa trong phương pháp này là:
#
#         - `abbreviation`: cột này có ý nghĩa là tên viết tắt của quốc gia.
#         - `capital_city`: Giá trị tên thủ đô của quốc gia.
#         - `updated`: Thời gian cập nhật của dữ liệu, theo mình quan sát thì dữ liệu của các quốc gia hầu như đều được cập nhật có thời gian khá tương tự nhau.
#
#     - Tiếp theo là 2 giá trị hiển thị vị trí của quốc gia:
#
#         - `loacation`: Khu vực quốc gia ở châu lục.
#
#         - `continent`: Lục địa của quốc gia.
#
#     - Ngoài ra sau lần tiền xử lí 1, thì chúng ta thấy thuộc tính `elevation_in_meters` có giá trị thiếu khá nhiều nên ở lần tiền xử lí lần 2 này, em quyết định xóa cột `elevation_in_meters`.
#
#     - Thuộc tính `life_expectancy` là giá trị hiển trị độ tuổi của quốc gia, em nghĩ chúng sẽ không liên quan đến một đại dịch như là **Covid-19** cho lắm. Ví dụ là các nước như **Mỹ**,**Pháp**,**Anh**...
#
#
# Mô hình nhóm chọn là cả 2 **`MLPRegressor`** và **`SoftmaxRegression`**.

# %% [markdown]
# ### Tách tập validation từ tập train

# %% [markdown]
# - Em sẽ chia tập `validation` bằng **20%** và tập `train` **còn lại** là **80%**

# %%
train_3_X, val_3_X, train_3_y, val_3_y = train_test_split(train_X,train_y,test_size=0.2, random_state=0)

# %% [markdown]
# ### Tiền xử lí ( tập huấn luyện )

# %% [markdown]
# **Class Tiền xử lí**
#
#    - Class này sẽ xóa các cột `abbreviation`, `capital_city`, `updated`,`location`,`continent`,`elevation_in_meters`.
#
#
#    - Chuyển dữ liệu cột `deaths` thành **5** khoảng như sau(nguyên nhân, mình có đề cập và thực hiện ở phần ***Khám phá dữ liệu***):
#
#         - 0 -> 100: Lưu vào **0**
#         - 100 -> 500: Lưu vào **1**
#         - 500 -> 1500: Lưu vào **2**
#         - 1500 -> 5000: Lưu vào **3**
#         - 5000 -> Max:  Lưu vào **4**

# %%
class ColAdderDropper_3(BaseEstimator, TransformerMixin):
    def fit(self, X_df, y=None):
        return self
    def transform(self, X_df, y=None):
        df = X_df.copy()
        unused_cols = ['abbreviation','capital_city', 'updated','location','continent','elevation_in_meters','life_expectancy']
        df=df.drop(unused_cols,axis=1)
        df=df.astype({'confirmed':'float64','recovered':'float64'})
        return df

# %% [markdown]
# **Fit và Transform tập `train_3_X` để xem dữ liệu sau khi tiền xử lí.**
#
# Xem 5 hàng đầu tiên của dữ liệu.

# %%
col_adderdropper = ColAdderDropper_3()
col_adderdropper.fit(train_3_X)
col_adderdropper.transform(train_3_X).head()
# Out:
#             confirmed  recovered  population  sq_km_area    iso        lat  \
# Country
# Zambia        20997.0    18773.0  17094130.0    752618.0  894.0 -13.133897
# Luxembourg    46415.0    40978.0    583455.0      2586.0  442.0  49.815300
# Bhutan          689.0      449.0    807610.0     47000.0   64.0  27.514200
# Mozambique    18642.0    16663.0  29668834.0    801590.0  508.0 -18.665695
# Eritrea        1252.0      643.0   5068831.0    117600.0  232.0  15.179400
#
#                  long
# Country
# Zambia      27.849332
# Luxembourg   6.129600
# Bhutan      90.433600
# Mozambique  35.529562
# Eritrea     39.782300

# %% [markdown]
# **Kiểu dữ liệu của các cột sau xử lí**
#
# Tất cả đều là float.

# %%
col_adderdropper.transform(train_3_X).dtypes
# Out:
# confirmed     float64
# recovered     float64
# population    float64
# sq_km_area    float64
# iso           float64
# lat           float64
# long          float64
# dtype: object

# %% [markdown]
# **Kích thước tập sau khi tiền xử lí**

# %%
col_adderdropper.transform(train_3_X).shape
# Out:
# (110, 7)

# %% [markdown]
# **Thống kê các giá trị NA của từng cột**

# %%
col_adderdropper.transform(train_3_X).isna().sum()
# Out:
# confirmed      0
# recovered      0
# population     1
# sq_km_area     1
# iso            2
# lat           13
# long          13
# dtype: int64

# %% [markdown]
# #### Điền giá trị thiếu

# %% [markdown]
# - Sau khi loại bỏ các cột mà em nghĩ là không cần thiết thì chúng ta còn lại các cột sau đây: `confirmed`,`recovered`,`population`,`sq_km_area`,`lat`,`iso`,`long`.
#
#
# - Trong đó:
#
#     - Các cột dạng số là `confirmed`,`recovered`,`population`,`sq_km_area`,`life_expectancy`,`iso`,`elevation_in_meters`. Chúng ta sẽ điền vào các giá trị thiếu các cột này bằng phương pháp mean.
#
#
# - Sau đó chúng ta sẽ dùng hàm chuẩn hóa `StandardScaler` của **Sklearn** để các thuật toán cực tiểu hóa hội tụ nhanh hơn.

# %%
nume_cols=['confirmed','recovered','population','sq_km_area','iso','lat','long']
mean = SimpleImputer(strategy='mean')
colTransform = ColumnTransformer([('mean_for_nume_cols',mean, nume_cols)])
colNormalize = StandardScaler(with_mean=False)
preprocess_pipeline = make_pipeline(col_adderdropper,colTransform,colNormalize)
preprocessed_train_X=preprocess_pipeline.fit_transform(train_3_X)
preprocess_pipeline
# Out:
# Pipeline(steps=[('coladderdropper_3', ColAdderDropper_3()),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('mean_for_nume_cols',
#                                                   SimpleImputer(),
#                                                   ['confirmed', 'recovered',
#                                                    'population', 'sq_km_area',
#                                                    'iso', 'lat', 'long'])])),
#                 ('standardscaler', StandardScaler(with_mean=False))])

# %% [markdown]
# ### Mô hình **`MLPRegressor`**
#
# Các bước thực hiện tương tự giống phương pháp 1, chỉ khác ở Class **`col_adderdropper`**

# %% [markdown]
# **Tìm các giá trị `best_alpha`, `best_iter`, `best_hidden_layer`.**

# %%
warnings.filterwarnings('ignore')
mlpclassifier = MLPClassifier(activation='tanh', solver='lbfgs', random_state=0)
full_pipeline_3a = make_pipeline(col_adderdropper, colTransform, colNormalize, mlpclassifier)
train_errs = []
val_errs = []
alphas = [0.1, 1, 10, 100, 1000]
max_iter= [100,500,1000,2000,2500]
hidden_layer_sizes=[2,5,10,20,40]
best_val_err = float('inf'); best_alpha = None;best_iter=None;best_hidden_layer=None
for hidden_layer in hidden_layer_sizes:
    for iter_ in max_iter:
        for alpha in alphas:
            full_pipeline.set_params(mlpclassifier__alpha=alpha,mlpclassifier__max_iter=iter_,\
                                     mlpclassifier__hidden_layer_sizes=hidden_layer)
            full_pipeline.fit(train_3_X, train_3_y)
            full_pipeline.predict(val_3_X)
            train_score = full_pipeline.score(train_3_X,train_3_y)
            val_score = full_pipeline.score(val_3_X, val_3_y)
            train_err, val_err = (1 - train_score) * 100, (1 - val_score) * 100
            train_errs.append(train_err)
            val_errs.append(val_err)
            if best_val_err > val_err:
                best_val_err = val_err
                best_alpha = alpha
                best_iter=iter_
                best_hidden_layer=hidden_layer

# %% [markdown]
# **In các giá trị tốt nhất vừa tìm được**

# %%
print("best_val_err : ", best_val_err)
print("best_alpha : " ,best_alpha)
print("best_iter :",best_iter)
print("best_hidden_layer",best_hidden_layer)
# Out:
# best_val_err :  35.71428571428571
# best_alpha :  0.1
# best_iter : 500
# best_hidden_layer 2

# %% [markdown]
# **Đồ thị 2 độ lỗi train và validation**

# %%
val_errs = np.array(val_errs)
train_errs=np.array(train_errs)
plt.figure(figsize=(30,20))
plt.plot(val_errs)
plt.plot(train_errs)
plt.show()

# %% [markdown]
# #### Nhận xét :
#
# **Đường màu xanh là giá trị validation_err**
#
# **Đường màu cam là giá trị train_err**
#
# **Với các giá trị siêu tham số càng lớn, thì dữ liệu càng bị OverFitting**

# %% [markdown]
# **Huấn luyện lại `full_pipeline` trên `train_X` và `train_y` (tập huấn luyện + tập validation) với `best_alpha`,`best_iter` và `best_hidden_layer` tìm được ở trên để ra được mô hình cụ thể cuối cùng.**

# %%
full_pipeline_3a.set_params(mlpclassifier__max_iter=iter_,mlpclassifier__alpha=best_alpha,\
                         mlpclassifier__hidden_layer_sizes=best_hidden_layer)
full_pipeline_3a.fit(train_X, train_y)
# Out:
# Pipeline(steps=[('coladderdropper_3', ColAdderDropper_3()),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('mean_for_nume_cols',
#                                                   SimpleImputer(),
#                                                   ['confirmed', 'recovered',
#                                                    'population', 'sq_km_area',
#                                                    'iso', 'lat', 'long'])])),
#                 ('standardscaler', StandardScaler(with_mean=False)),
#                 ('mlpclassifier',
#                  MLPClassifier(activation='tanh', alpha=0.1,
#                                hidden_layer_sizes=2, max_iter=2500,
#                                random_state=0, solver='lbfgs'))])

# %% [markdown]
# #### Kiểm tra cuối cùng
# **Kiểm tra cuối cùng của mô hình với tập test.**
#
# Khi thay đổi tập dữ liệu thì với cùng 1 mô hình **`MLPClassifier`** , độ chính xác đã tăng lên từ **0.71** lên **0.77**

# %%
score_3a = full_pipeline_3a.score(test_X,test_y)
score_3a
# Out:
# 0.7714285714285715

# %% [markdown]
# ### Mô hình **`SoftmaxRegression`**
#
# Các bước thực hiện tương tự giống `phương pháp 2`, chỉ khác ở Class **`col_adderdropper`**

# %% [markdown]
# **Khởi tạo mô hình**

# %%
logregmodel = LogisticRegression(multi_class='multinomial')
full_pipeline_3b = make_pipeline(col_adderdropper, colTransform, colNormalize,logregmodel)
full_pipeline_3b
# Out:
# Pipeline(steps=[('coladderdropper_3', ColAdderDropper_3()),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('mean_for_nume_cols',
#                                                   SimpleImputer(),
#                                                   ['confirmed', 'recovered',
#                                                    'population', 'sq_km_area',
#                                                    'iso', 'lat', 'long'])])),
#                 ('standardscaler', StandardScaler(with_mean=False)),
#                 ('logisticregression',
#                  LogisticRegression(multi_class='multinomial'))])

# %% [markdown]
# **Tìm các giá trị `best_C`, `best_iter`.**

# %%
warnings.filterwarnings('ignore')
train_errs = []
val_errs = []
C = [1, 10, 100, 1000, 10000, 100000]
max_iters= [100, 500, 1000, 2000, 2500]
best_val_err = float('inf'); best_C = None;best_iter=None

for c in C:
    for iter_ in max_iters:
        full_pipeline_2.set_params(logisticregression__C=c,logisticregression__max_iter= iter_)
        full_pipeline_2.fit(train_3_X, train_3_y)
        full_pipeline_2.predict(val_2_X)
        train_score = full_pipeline_2.score(train_3_X,train_3_y)
        val_score = full_pipeline_2.score(val_3_X, val_3_y)
        train_err, val_err = (1 - train_score) * 100, (1 - val_score) * 100
        train_errs.append(train_err)
        val_errs.append(val_err)
        if best_val_err > val_err:
            best_val_err = val_err
            best_C = c
            best_iter=iter_

# %% [markdown]
# **In các giá trị tốt nhất vừa tìm được**

# %%
print("best_val_err :" , best_val_err)
print("best_C :",best_C)
print("best_iter :", best_iter)
# Out:
# best_val_err : 32.14285714285714
# best_C : 100
# best_iter : 500

# %% [markdown]
# **Trực quan hóa kết quả**

# %%
train_errs_df = pd.DataFrame(data=np.array(train_errs).reshape(len(C), -1),
                             index=C, columns=max_iters)
val_errs_df = pd.DataFrame(data=np.array(val_errs).reshape(len(C), -1), 
                           index=C, columns=max_iters)
min_err = min(min(train_errs), min(val_errs))
max_err = max(max(train_errs), max(val_errs))
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)

sns.heatmap(train_errs_df,vmin=min_err, vmax=max_err, square=True, annot=True, 
            cbar=False, fmt='.1f', cmap='Reds')
plt.title('train errors'); plt.xlabel('max_iters'); plt.ylabel('C');

min_err = min(min(train_errs), min(val_errs))
max_err = max(max(train_errs), max(val_errs))
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)

sns.heatmap(val_errs_df,vmin=min_err, vmax=max_err, square=True, annot=True, 
            cbar=False, fmt='.1f', cmap='Reds')
plt.title('validation errors'); plt.xlabel('max_iters'); plt.ylabel('C');

# %% [markdown]
# #### Đánh giá sơ bộ
# **Với các siêu tham số càng lớn thì mô hình bị OverFitting càng nhiều**

# %% [markdown]
# **Huấn luyện lại `full_pipeline` trên `train_X` và `train_y` (tập huấn luyện + tập validation) với `best_alpha`,`best_iter` và `best_hidden_layer` tìm được ở trên để ra được mô hình cụ thể cuối cùng.**

# %%
full_pipeline_3b.set_params(logisticregression__C=best_C,logisticregression__max_iter= best_iter)
full_pipeline_3b.fit(train_X, train_y)
# Out:
# Pipeline(steps=[('coladderdropper_3', ColAdderDropper_3()),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('mean_for_nume_cols',
#                                                   SimpleImputer(),
#                                                   ['confirmed', 'recovered',
#                                                    'population', 'sq_km_area',
#                                                    'iso', 'lat', 'long'])])),
#                 ('standardscaler', StandardScaler(with_mean=False)),
#                 ('logisticregression',
#                  LogisticRegression(C=100, max_iter=500,
#                                     multi_class='multinomial'))])

# %% [markdown]
# #### Kiểm tra cuối cùng
#
# **Kiểm tra cuối cùng của mô hình với tập test.**
#
# Khi thay đổi tập dữ liệu thì với cùng 1 mô hình **`SoftmaxRegression`** , độ chính xác đã tăng lên.Từ **0.54** tăng lên **0.71**

# %%
score_3b = full_pipeline_3b.score(test_X,test_y)
score_3b
# Out:
# 0.7142857142857143
